# %%
include("MyLib.jl")
using Plots
using .MyLib
function func(x)
    return x^2
end
function CheckMydiff()
    x=0:0.1:2
    y=func.(x)
    h=x[2]-x[1]
    dydx=MyLib.diff1st(h,y)
    ddyddx=MyLib.diff2nd(h,y)
    plot(xlabel="x",ylabel="y",title="check My diff",legend=:bottomright)
    plot!(x,y,label="y=x")
    plot!(x,dydx,label="y=dydx")
    plot!(x,ddyddx)
end
CheckMydiff()

# %%
include("TestMain.jl")
TestInitPot()
# Out:
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
CheckABC()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
CheckHmat()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
@time TestInitialCondition()
# Out:
# (l,j,E)=(0,0.5,-54.58248573976863)
# (l,j,E)=(0,0.5,-43.23534694612556)
# (l,j,E)=(1,1.5,-36.82109073057429)
# (l,j,E)=(1,0.5,-35.974448804072026)
# (l,j,E)=(2,2.5,-29.83353127719407)
# (l,j,E)=(2,1.5,-28.09904416713546)
# (l,j,E)=(0,0.5,-27.408511837604536)
# (l,j,E)=(3,3.5,-22.547493266608342)
# (l,j,E)=(1,1.5,-19.74385917060846)
# (l,j,E)=(3,2.5,-19.714562721778137)
# (l,j,E)=(1,0.5,-18.566653679568134)
# (l,j,E)=(4,4.5,-15.044535608089063)
# (l,j,E)=(2,2.5,-11.843679145491663)
# (l,j,E)=(4,3.5,-10.983983136924508)
# (l,j,E)=(2,1.5,-9.77007841708837)
# (l,j,E)=(5,5.5,-7.427381593389541)
# (l,j,E)=(3,3.5,-4.32248524446571)
# (l,j,E)=(1,1.5,-2.972159301082044)
# (l,j,E)=(5,4.5,-2.1779200216768118)
# (l,j,E)=(1,0.5,-2.027853419274848)
# (l,j,E)=(3,2.5,-1.6252147675678827)
# (l,j,E)=(1,0.5,-0.018087589743487342)
# (l,j,E)=(1,1.5,-0.015478015597679473)
# (l,j,E)=(2,1.5,0.0004168297258786424)
# (l,j,E)=(2,2.5,0.00207354585532471)
# (l,j,E)=(3,2.5,0.045331019799647265)
# (l,j,E)=(3,3.5,0.046092003540394444)
# (l,j,E)=(6,6.5,0.13416349806793448)
# (l,j,E)=(4,3.5,0.14167782610623192)
# (l,j,E)=(4,4.5,0.1419160055789206)
# (l,j,E)=(2,2.5,0.2610299596217658)
# (l,j,E)=(2,1.5,0.2660746194092667)
# (l,j,E)=(5,4.5,0.2878211688218073)
# (l,j,E)=(5,5.5,0.28785491765060556)
# (l,j,E)=(6,6.5,0.48716555359902713)
# (l,j,E)=(6,5.5,0.4872503063669882)
# (l,j,E)=(3,3.5,0.5338367966466109)
# (l,j,E)=(3,2.5,0.5361504443750675)
# (l,j,E)=(7,6.5,0.7412690961593285)
# (l,j,E)=(7,7.5,0.7412712600094267)
# (l,j,E)=(4,4.5,0.86804557182559)
# (l,j,E)=(4,3.5,0.8706588466962302)
# (l,j,E)=(5,5.5,1.2838268138990117)
# (l,j,E)=(5,4.5,1.2840929151804659)
# (l,j,E)=(6,5.5,1.7691147093762822)
# (l,j,E)=(6,6.5,1.7693809142610206)
# (l,j,E)=(4,4.5,1.8927712829211316)
# (l,j,E)=(4,3.5,2.3228510253550354)
# (l,j,E)=(7,7.5,2.3262600198447245)
# (l,j,E)=(7,6.5,2.3262992939732783)
# (l,j,E)=(5,5.5,3.0789213809040916)
# (l,j,E)=(5,4.5,3.094081207158908)
# (l,j,E)=(6,5.5,3.8868831563292616)
# (l,j,E)=(6,6.5,3.903424219928084)
# (l,j,E)=(7,7.5,4.779209651865756)
# (l,j,E)=(7,6.5,4.785905624215999)
# (l,j,E)=(6,5.5,5.834922791560317)
# (l,j,E)=(7,7.5,7.069650102497391)
# (l,j,E)=(7,6.5,7.993576120771593)
#   4.011895 seconds (1.02 M allocations: 66.838 MiB, 1.67% gc time, 1.49% compilation time)
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
