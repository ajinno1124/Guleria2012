# %%
include("Main.jl")
using Profile
using ProfileView
Profile.init(delay=0.0005)
Profile.clear()
AN=AtomNum(82,126,1)
Profile.@profile HF_iter(AN,NParamType="SLy4",LParamType="HPL2")
Profile.print()
# Out:
# diffρ=(0.14655482606357215,0.08030782639599188,1.1359224725727733e-5)
# 1
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.023849909131875825,0.01987283522508223,2.2951375402393856e-6)
# 2
# diffρ=(0.0002169209880755679,0.0005034267946542444,7.64906423000116e-8)
# 3
# diffρ=(2.858118626784665e-5,4.495361919932953e-5,1.7235028944890506e-8)
# 4
# diffρ=(5.525171937852971e-6,1.1219423260737223e-5,3.0826502404694975e-9)
# 5
# diffρ=(1.8374328854027378e-6,3.087531644049709e-6,1.5472297176514467e-9)
# Overhead ╎ [+additional indent] Count File:Line; Function
# ...
#     1╎1      ...tinterpretation.jl:0; abstract_call_gf_by_type(int...
#     1╎1      ...tinterpretation.jl:0; maybe_get_const_prop_profita...
#     1╎1      ...mpiler/optimize.jl:616; renumber_ir_elements!(body::...
#     1╎1      .../ssair/inlining.jl:0; process_simple!(ir::Core.Com...
# ...
