# %%
include("MomFit.jl")
Fit_Mom("Givendata/Momentum_Dependence/GKW2+Kohno_mom.csv")
# Out:
# k_cutoff=2.5
#
# degree of freedom = 23
# const, aΛ2 = [-29.098371987745747, 32.293882105765896]
# WARNING: redefinition of constant k_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit.jl")
Fit_Mom("Givendata/Momentum_Dependence/GKW3+Kohno_mom.csv")
# Out:
# k_cutoff=2.5
#
# degree of freedom = 23
# const, aΛ2 = [-28.278161390800726, 35.9815923495766]

# %%
include("MomFit.jl")
k_cutoff=1.0
Fit_Mom("Givendata/Momentum_Dependence/k1_Uinf0_mom.csv")
# Out:
# k_cutoff=1.0
#
# degree of freedom = 8
# const, aΛ2 = [-29.95328507758867, 40.95591466722299]
# WARNING: redefinition of constant k_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit.jl")
Fit_Dense("Givendata/SNM2BF_lower.csv",isSNM=true,ParamType="MD1_2.5")
# Out:
# degree of freedom = 24
# aΛ4, aΛ5 = [-1342.8741868801205, 1679.078646521994]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-0.8916981326163567, 32.293882105765896, -1342.8741868801205, 1679.078646521994]
# WARNING: redefinition of constant k_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit.jl")
Fit_Dense("Givendata/SNM2BF_upper.csv",isSNM=true,ParamType="MD1_2.5")
# Out:
# degree of freedom = 22
# aΛ4, aΛ5 = [-1369.9242059957785, 1746.7755078704422]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-0.9177543128738391, 32.293882105765896, -1369.9242059957785, 1746.7755078704422]

# %%
include("MomFit.jl")
ρ_cutoff=2.8
Fit_Dense("Givendata/SNM3BF_lower.csv",isSNM=true,ParamType="MD2_2.5")
# Out:
# degree of freedom = 24
# aΛ4, aΛ5 = [-953.8463230137958, 1605.5950753795275]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-180.63583418075322, 35.9815923495766, -953.8463230137958, 1605.5950753795275]
# WARNING: redefinition of constant ρ_cutoff. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant ρ_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit.jl")
ρ_cutoff=2.9
Fit_Dense("Givendata/SNM3BF_upper.csv",isSNM=true,ParamType="MD2_2.5")
# Out:
# degree of freedom = 26
# aΛ4, aΛ5 = [-1637.7941455303524, 2290.5994391150143]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-1.002478566352179, 35.9815923495766, -1637.7941455303524, 2290.5994391150143]
# WARNING: redefinition of constant ρ_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit.jl")
Fit_Dense("Givendata/SNM3BF_lower.csv",isSNM=true,ParamType="MD3_1.0")
# Out:
# degree of freedom = 26
# aΛ4, aΛ5 = [-1465.819087383902, 1945.0440224068402]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-1.0349252739150916, 40.95591466722299, -1465.819087383902, 1945.0440224068402]
# WARNING: redefinition of constant ρ_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit.jl")
Fit_Dense("Givendata/SNM3BF_upper.csv",isSNM=true,ParamType="MD3_1.0")
# Out:
# degree of freedom = 27
# aΛ4, aΛ5 = [-1627.629338679154, 2257.506638042394]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-1.0683139423870256, 40.95591466722299, -1627.629338679154, 2257.506638042394]
