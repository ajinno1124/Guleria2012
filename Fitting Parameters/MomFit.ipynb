# %%
include("MomFit.jl")
Fit_Mom("Givendata/Momentum_Dependence/GKW2+Kohno_mom.csv")
# Out:
# LoadError: syntax: missing comma or ) in argument list
# in expression starting at C:\Users\jinno\OneDrive\progmrams\Guleria2012\Fitting Parameters\MomFit.jl:69
#
# Stacktrace:
#  [1] top-level scope
#    @ C:\Users\jinno\OneDrive\progmrams\Guleria2012\Fitting Parameters\MomFit.jl:69
#  [2] include(fname::String)
#    @ Base.MainInclude .\client.jl:451
#  [3] top-level scope
#    @ In[31]:1
#  [4] eval
#    @ .\boot.jl:373 [inlined]
#  [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
include("MomFit.jl")
Fit_Mom("Givendata/Momentum_Dependence/GKW3+Kohno_mom.csv")
# Out:
# k_cutoff=2.5
#
# degree of freedom = 23
# const, aΛ2 = [-28.278161390790633, 5.97294433002585]
# WARNING: redefinition of constant k_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit.jl")
k_cutoff=1.0
Fit_Mom("Givendata/Momentum_Dependence/k1_Uinf0_mom.csv")
# Out:
# k_cutoff=1.0
#
# degree of freedom = 8
# const, aΛ2 = [-29.95328507758762, 6.79868183475533]
# WARNING: redefinition of constant k_cutoff. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant k_cutoff. This may fail, cause incorrect answers, or produce other errors.
