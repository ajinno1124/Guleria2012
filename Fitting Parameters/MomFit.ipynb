# %%
include("MomFit.jl")
Fit_Mom("Givendata/Momentum_Dependence/GKW2+Kohno_mom.csv")
# Out:
# k_cutoff=2.5
#
# degree of freedom = 23
# const, aΛ2 = [-29.098371987741686, 5.360784429556326]
# WARNING: Method definition (::Main.var"#Func#2"{aL2, C})(Any, Any) in module Main at C:\Users\jinno\OneDrive\progmrams\Guleria2012\Fitting Parameters\MomFit.jl:128 overwritten at C:\Users\jinno\OneDrive\progmrams\Guleria2012\Fitting Parameters\MomFit.jl:131.

# %%
include("MomFit.jl")
Fit_Mom("Givendata/Momentum_Dependence/GKW3+Kohno_mom.csv")
# Out:
# k_cutoff=2.5
#
# degree of freedom = 23
# const, aΛ2 = [-28.278161390790633, 5.97294433002585]
# WARNING: Method definition (::Main.var"#Func#4"{aL2, C})(Any, Any) in module Main at C:\Users\jinno\OneDrive\progmrams\Guleria2012\Fitting Parameters\MomFit.jl:128 overwritten at C:\Users\jinno\OneDrive\progmrams\Guleria2012\Fitting Parameters\MomFit.jl:131.

# %%
include("MomFit.jl")
k_cutoff=1.0
Fit_Mom("Givendata/Momentum_Dependence/k1_Uinf0_mom.csv")
# Out:
# k_cutoff=1.0
#
# degree of freedom = 8
# const, aΛ2 = [-29.95328507758762, 6.79868183475533]
# WARNING: Method definition (::Main.var"#Func#6"{aL2, C})(Any, Any) in module Main at C:\Users\jinno\OneDrive\progmrams\Guleria2012\Fitting Parameters\MomFit.jl:128 overwritten at C:\Users\jinno\OneDrive\progmrams\Guleria2012\Fitting Parameters\MomFit.jl:131.
# WARNING: redefinition of constant k_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit.jl")
Fit_Dense("Givendata/SNM2BF_lower.csv",isSNM=true,ParamType="MD1_2.5")
# Out:
# degree of freedom = 24
# aΛ4, aΛ5 = [-739.5685791518517, 1326.706997369792]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-200.61040713384594, 5.360784429556326, -739.5685791518517, 1326.706997369792]

# %%
include("MomFit.jl")
Fit_Dense("Givendata/SNM2BF_upper.csv",isSNM=true,ParamType="MD1_2.5")
# Out:
# degree of freedom = 22
# aΛ4, aΛ5 = [-1369.9242059711867, 1844.2067470088964]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-0.9177543128895577, 5.360784429556326, -1369.9242059711867, 1844.2067470088964]

# %%
include("MomFit.jl")
Fit_Dense("Givendata/SNM3BF_lower.csv",isSNM=true,ParamType="MD2_2.5")
# Out:
# degree of freedom = 26
# aΛ4, aΛ5 = [-930.5845704772076, 1671.7750348272998]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-177.71866838542815, 5.97294433002585, -930.5845704772076, 1671.7750348272998]

# %%
include("MomFit.jl")
ρ_cutoff=2.9
Fit_Dense("Givendata/SNM3BF_upper.csv",isSNM=true,ParamType="MD2_2.5")
# Out:
# degree of freedom = 26
# aΛ4, aΛ5 = [-1637.7941455328719, 2399.1565682530672]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-1.002478566349898, 5.97294433002585, -1637.7941455328719, 2399.1565682530672]
# WARNING: redefinition of constant ρ_cutoff. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant ρ_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit.jl")
Fit_Dense("Givendata/SNM3BF_lower.csv",isSNM=true,ParamType="MD3_1.0")
# Out:
# degree of freedom = 26
# aΛ4, aΛ5 = [-930.7628467354051, 1668.9232078352625]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-177.6609895795445, 6.79868183475533, -930.7628467354051, 1668.9232078352625]

# %%
include("MomFit.jl")
Fit_Dense("Givendata/SNM3BF_upper.csv",isSNM=true,ParamType="MD3_1.0")
# Out:
# degree of freedom = 27
# aΛ4, aΛ5 = [-1109.6546153618356, 1994.3191090089538]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-172.20192785998321, 6.79868183475533, -1109.6546153618356, 1994.3191090089538]
