# %%
include("MomFit_unfix_const.jl")
Fit_Mom2("Givendata/Momentum_Dependence/GKW2+Kohno_mom.csv")
# Out:
# k_cutoff=1.0
#
# degree of freedom = 9
# aΛ2 = [40.84151607273452]
# WARNING: redefinition of constant k_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit_unfix_const.jl")
Fit_Mom2("Givendata/Momentum_Dependence/GKW3+Kohno_mom.csv")
# Out:
# k_cutoff=1.0
#
# degree of freedom = 9
# aΛ2 = [53.53651324877708]

# %%
include("MomFit_unfix_const.jl")
Fit_Dense2("Givendata/SNM2BF_lower.csv",isSNM=true,ParamType="Kohno2_1.0")
# Out:
# degree of freedom = 52
# aΛ1, aΛ4, aΛ5 = [-397.0001008371326, -188.15044915006058, 830.3658631867067]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-397.0001008371326, 40.84151607273452, -188.15044915006058, 830.3658631867067]

# %%
include("MomFit_unfix_const.jl")
Fit_Dense2("Givendata/SNM2BF_upper.csv",isSNM=true,ParamType="Kohno2_1.0")
# Out:
# degree of freedom = 52
# aΛ1, aΛ4, aΛ5 = [-307.41664803595387, -525.746798802143, 1160.4734249991761]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-307.41664803595387, 40.84151607273452, -525.746798802143, 1160.4734249991761]
# WARNING: redefinition of constant ρ_cutoff. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant k_cutoff. This may fail, cause incorrect answers, or produce other errors.

# %%
include("MomFit_unfix_const.jl")
Fit_Dense2("Givendata/SNM3BF_lower.csv",isSNM=true,ParamType="Kohno3_1.0")
# Out:
# degree of freedom = 49
# aΛ1, aΛ4, aΛ5 = [-414.4431425579929, -296.3738273805336, 1118.415789933032]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-414.4431425579929, 53.53651324877708, -296.3738273805336, 1118.415789933032]

# %%
include("MomFit_unfix_const.jl")
Fit_Dense2("Givendata/SNM3BF_upper.csv",isSNM=true,ParamType="Kohno3_1.0")
# Out:
# degree of freedom = 49
# aΛ1, aΛ4, aΛ5 = [-362.1104549166952, -514.970842035042, 1349.8076360666685]
# aΛ1, aΛ2, aΛ4, aΛ5 = [-362.1104549166952, 53.53651324877708, -514.970842035042, 1349.8076360666685]
