# %%
include("ChiralFit.jl")
FittingMain("./Givendata/SNM2BF_lower.csv",isSNM=true)
# Out:
# degree of freedom = 23
# aΛ1,aΛ2,aΛ4 = [-809.1789955328932, -18.807186402590386, 1131.0318494653418]
# WARNING: redefinition of constant ρ_cutoff. This may fail, cause incorrect answers, or produce other errors.
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.

# %%
include("ChiralFit.jl")
Calc_GKWCoef1()
# Out:
# GKW2: [γ,u0,u1,u2,u3,u3p,y0,y3]
# = [0.3333333333333333, -968.125, -125.44938856118907, -376.34816568356723, 0.0, 4371.717378386592, 0.0, 0.0]
#
# GKW3: [γ,u0,u1,u2,u3,u3p,y0,y3]
# = [0.3333333333333333, -500.62499999999994, 295.4508964244826, 886.3526892734478, 0.0, 4.912041998187181, 0.0, 0.0]
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.

# %%
include("ChiralFit.jl")
ComparePot()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
