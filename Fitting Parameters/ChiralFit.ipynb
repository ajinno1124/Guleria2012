# %%
include("ChiralFit.jl")
FittingMain("Givendata/SNM2BF_lower.csv",isSNM=true)
# Out:
# degree of freedom = 52
# aΛ1,aΛ4,aΛ5 = [-397.000100838668, -188.1504491438834, 978.1111975079277]

# %%
include("ChiralFit.jl")
FittingMain("Givendata/SNM2BF_upper.csv",isSNM=true)
# Out:
# degree of freedom = 52
# aΛ1,aΛ4,aΛ5 = [-307.4166479976713, -525.7467989527032, 1308.218759471724]

# %%
include("ChiralFit.jl")
FittingMain("Givendata/SNM3BF_lower.csv",isSNM=true)
# Out:
# degree of freedom = 49
# aΛ1,aΛ4,aΛ5 = [-414.44314255397654, -296.3738273964416, 1312.0856340005728]

# %%
include("ChiralFit.jl")
FittingMain("Givendata/SNM3BF_upper.csv",isSNM=true)
# Out:
# degree of freedom = 49
# aΛ1,aΛ4,aΛ5 = [-362.11045492096304, -514.9708420183217, 1543.4774801026947]

# %%
include("ChiralFit.jl")
Calc_GKWCoef1()
# Out:
# UndefVarError: Calc_GKWCoef1 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[8]:2
#  [2] eval
#    @ .\boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
include("ChiralFit.jl")
ComparePot()
# Out:
# UndefVarError: ComparePot not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[9]:2
#  [2] eval
#    @ .\boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196
