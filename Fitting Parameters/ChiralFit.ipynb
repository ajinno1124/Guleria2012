# %%
include("ChiralFit.jl")
FittingMain("./Givendata/SNM2BF_lower.csv",isSNM=true)
# Out:
# degree of freedom = 23
# aΛ1,aΛ2,aΛ4 = [-809.1789961419456, -18.807186803111527, 1131.031851361423]

# %%
include("ChiralFit.jl")
Calc_GKWCoef1()
# Out:
# GKW2: [γ,u0,u1,u2,u3,u3p,y0,y3]
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# UndefVarError: Calc_LParams not defined
#
# Stacktrace:
#  [1] Calc_GKWCoef1()
#    @ Main C:\Users\jinno\OneDrive\progmrams\Guleria2012\Fitting Parameters\ChiralFit.jl:96
#  [2] top-level scope
#    @ In[2]:2
#  [3] eval
#    @ .\boot.jl:373 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
include("ChiralFit.jl")
ComparePot()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# UndefVarError: getaΛ not defined
#
# Stacktrace:
#  [1] ComparePot()
#    @ Main C:\Users\jinno\OneDrive\progmrams\Guleria2012\Fitting Parameters\ChiralFit.jl:109
#  [2] top-level scope
#    @ In[3]:2
#  [3] eval
#    @ .\boot.jl:373 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196
