# %%
include("TestMain.jl")
TestInitPot()
#binを小さく取りすぎると、W/rの粗さが目立つ

# %%
include("TestMain.jl")
CheckInitABC()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestWronskyEuler()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
@time TestInitialCondition()
# Out:
# (occ,l,j,E)=(1.0,0,0.5,-40.857940673828125)
# (occ,l,j,E)=(1.0,1,1.5,-36.923248291015625)
# (occ,l,j,E)=(1.0,1,0.5,-36.549285888671875)
# (occ,l,j,E)=(1.0,2,2.5,-32.275360107421875)
# (occ,l,j,E)=(1.0,2,1.5,-31.347381591796875)
# (occ,l,j,E)=(1.0,0,0.5,-30.075149536132812)
# (occ,l,j,E)=(1.0,3,3.5,-27.033889770507812)
# (occ,l,j,E)=(1.0,3,2.5,-25.288619995117188)
# (occ,l,j,E)=(1.0,1,1.5,-23.774429321289062)
# (occ,l,j,E)=(1.0,1,0.5,-23.024642944335938)
# (occ,l,j,E)=(1.0,4,4.5,-21.284042358398438)
# (occ,l,j,E)=(1.0,4,3.5,-18.461074829101562)
# (occ,l,j,E)=(1.0,2,2.5,-17.164199829101562)
# (occ,l,j,E)=(1.0,2,1.5,-15.661300659179688)
# (occ,l,j,E)=(1.0,0,0.5,-15.328872680664062)
# (occ,l,j,E)=(1.0,5,5.5,-15.093513488769531)
# (occ,l,j,E)=(1.0,5,4.5,-10.955970764160156)
# (occ,l,j,E)=(1.0,3,3.5,-10.378288269042969)
# (occ,l,j,E)=(1.0,6,6.5,-8.520561218261719)
# (occ,l,j,E)=(1.0,1,1.5,-8.157096862792969)
# (occ,l,j,E)=(1.0,3,2.5,-8.016807556152344)
# ...

# %%
include("TestMain.jl")
TestDensity()
# Out:
#   1.206736 seconds (362.63 k allocations: 41.775 MiB, 12.38% gc time, 24.79% compilation time)
#   0.004565 seconds (374 allocations: 6.082 MiB)
# check Z=8: Integrate ρ=7.999999999999999
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestHFiter()
# Out:
# diffρ=(0.07100796304734072,0.0811737293922124,1.7107254017842026e-5)
# 1
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.01531946427172385,0.011269048596890438,8.853401976158817e-7)
# 2
# diffρ=(0.00037283635112783496,0.0003851169788594725,6.552685342066958e-9)
# 3
# diffρ=(5.851336627492215e-5,6.097613859446465e-5,3.293379165096055e-9)
# 4
# diffρ=(1.1672620911926854e-5,2.0631367238389258e-5,3.3760972819018477e-9)
# 5
# diffρ=(4.8877312348822655e-6,6.529058943659851e-6,1.2469213794212976e-9)
# (occ,l,j,E)=(0.5,0,0.5,-27.241470336914062)
# (occ,l,j,E)=(0.0,1,0.5,-22.874313354492188)
# (occ,l,j,E)=(0.0,1,1.5,-22.874313354492188)
# (occ,l,j,E)=(0.0,2,1.5,-17.786727905273438)
# (occ,l,j,E)=(0.0,2,2.5,-17.786727905273438)
# (occ,l,j,E)=(0.0,0,0.5,-16.113296508789062)
# (occ,l,j,E)=(0.0,3,2.5,-12.116584777832031)
# (occ,l,j,E)=(0.0,3,3.5,-12.116584777832031)
# ...
