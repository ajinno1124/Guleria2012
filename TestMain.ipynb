# %%
include("TestMain.jl")
TestInitPot()
#binを小さく取りすぎると、W/rの粗さが目立つ

# %%
include("TestMain.jl")
CheckInitABC()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestWronskyEuler()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
@time TestInitialCondition()
# Out:
# (occ,l,j,E)=(1.0,0,0.5,-40.910675048828125)
# (occ,l,j,E)=(1.0,1,1.5,-36.908599853515625)
# (occ,l,j,E)=(1.0,1,0.5,-36.537261962890625)
# (occ,l,j,E)=(1.0,2,2.5,-32.245330810546875)
# (occ,l,j,E)=(1.0,2,1.5,-31.325897216796875)
# (occ,l,j,E)=(1.0,0,0.5,-30.183609008789062)
# (occ,l,j,E)=(1.0,3,3.5,-26.980270385742188)
# (occ,l,j,E)=(1.0,3,2.5,-25.254898071289062)
# (occ,l,j,E)=(1.0,1,1.5,-23.643905639648438)
# (occ,l,j,E)=(1.0,1,0.5,-22.905929565429688)
# (occ,l,j,E)=(1.0,4,4.5,-21.196853637695312)
# (occ,l,j,E)=(1.0,4,3.5,-18.412216186523438)
# (occ,l,j,E)=(1.0,2,2.5,-16.951461791992188)
# (occ,l,j,E)=(1.0,2,1.5,-15.481185913085938)
# (occ,l,j,E)=(1.0,0,0.5,-15.298599243164062)
# (occ,l,j,E)=(1.0,5,5.5,-14.962684631347656)
# (occ,l,j,E)=(1.0,5,4.5,-10.889640808105469)
# (occ,l,j,E)=(1.0,3,3.5,-10.062767028808594)
# (occ,l,j,E)=(1.0,6,6.5,-8.338218688964844)
# (occ,l,j,E)=(1.0,3,2.5,-7.766304016113281)
# (occ,l,j,E)=(1.0,1,1.5,-7.680030822753906)
# ...

# %%
include("TestMain.jl")
TestDensity()
# Out:
#   0.360320 seconds (373.87 k allocations: 21.122 MiB, 7.45% gc time, 91.21% compilation time)
#   0.000255 seconds (168 allocations: 448.125 KiB)
# ...

# %%
include("TestMain.jl")
@time CheckCalc_Coef()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# MethodError: no method matching Calc_Coef(::Vector{Vector{Float64}}, ::Vector{Vector{SingleParticleState}}, ::Vector{Float64}, ::Vector{Float64}, ::Main.NuclParameters.NuclParams, ::Main.LambdaParameters.LambdaParams, ::Int64)
# Closest candidates are:
#   Calc_Coef(::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any) at ~/ドキュメント/Guleria2012/Main.jl:431
#
# Stacktrace:
#  [1] CheckCalc_Coef(; NParamType::String, ΛParamType::String)
#    @ Main ~/ドキュメント/Guleria2012/TestMain.jl:131
#  [2] CheckCalc_Coef()
#    @ Main ~/ドキュメント/Guleria2012/TestMain.jl:121
#  [3] top-level scope
#    @ ./timing.jl:220 [inlined]
#  [4] top-level scope
#    @ ./In[6]:0
#  [5] eval
#    @ ./boot.jl:373 [inlined]
#  [6] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
include("TestMain.jl")
TestHFiter()
# Out:
# -0.4951627723254186
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.010622505397124785,0.011144745512875953,0.0)
# 1
# -0.35343184478105677
# diffρ=(0.0008278744635223544,0.0008294365778499803,0.0)
# 2
# -0.3166437132532186
# diffρ=(1.9891693180241827e-5,2.050632250376041e-5,0.0)
# 3
# -0.30341822493720444
# diffρ=(2.3038868870796254e-7,2.4756809759540817e-7,0.0)
# (occ,l,j,E)=(1.0,0,0.5,-13.018119812011719)
# -0.29002789020503056

# %%
include("Main.jl")
HF_iter(AtomNum(2,2,0))
# Out:
# -0.4951627723254186
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.010622505397124785,0.011144745512875953,0.0)
# 1
# -0.35343184478105677
# diffρ=(0.0008278744635223544,0.0008294365778499803,0.0)
# 2
# -0.3166437132532186
# diffρ=(1.9891693180241827e-5,2.050632250376041e-5,0.0)
# 3
# -0.30341822493720444
# diffρ=(2.3038868870796254e-7,2.4756809759540817e-7,0.0)
# ...

# %%
0.05^4
# Out:
# 6.250000000000003e-6
