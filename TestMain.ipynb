# %%
include("TestMain.jl")
TestInitPot()
#binを小さく取りすぎると、W/rの粗さが目立つ
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# WARNING: redefinition of constant Nmesh. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant Nmatch. This may fail, cause incorrect answers, or produce other errors.

# %%
include("TestMain.jl")
CheckInitABC()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestWronskyEuler()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
@time TestInitialCondition()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# (occ,l,j,E)=(1.0,0,0.5,-53.586517333984375)
# (occ,l,j,E)=(1.0,1,1.5,-49.428985595703125)
# (occ,l,j,E)=(1.0,1,0.5,-49.013275146484375)
# (occ,l,j,E)=(1.0,2,2.5,-44.522979736328125)
# (occ,l,j,E)=(1.0,2,1.5,-43.488922119140625)
# (occ,l,j,E)=(1.0,0,0.5,-42.163848876953125)
# (occ,l,j,E)=(1.0,3,3.5,-38.986724853515625)
# (occ,l,j,E)=(1.0,3,2.5,-37.033294677734375)
# (occ,l,j,E)=(1.0,1,1.5,-35.422088623046875)
# (occ,l,j,E)=(1.0,1,0.5,-34.571014404296875)
# (occ,l,j,E)=(1.0,4,4.5,-32.906097412109375)
# (occ,l,j,E)=(1.0,4,3.5,-29.725265502929688)
# (occ,l,j,E)=(1.0,2,2.5,-28.299880981445312)
# (occ,l,j,E)=(1.0,2,1.5,-26.557907104492188)
# (occ,l,j,E)=(1.0,5,5.5,-26.346054077148438)
# (occ,l,j,E)=(1.0,0,0.5,-26.190383911132812)
# (occ,l,j,E)=(0.0,5,4.5,-21.638687133789062)
# (occ,l,j,E)=(0.0,3,3.5,-20.881210327148438)
# ...

# %%
include("TestMain.jl")
TestDensity()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
#   0.767311 seconds (4.84 M allocations: 373.731 MiB, 12.88% gc time, 61.14% compilation time)
#   0.000543 seconds (3.99 k allocations: 622.922 KiB)
# check Z=8: Integrate ρ=7.999999999999999

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType="HPL2")
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# MethodError: no method matching getaL(::String)
# Closest candidates are:
#   getaL(::Int64) at ~/ドキュメント/Guleria2012/SkyrmeParams.jl:412
#
# Stacktrace:
#  [1] HF_iter(AN::AtomNum; MaxIter::Int64, NParamType::String, LParamType::String, α::Float64)
#    @ Main ~/ドキュメント/Guleria2012/Main.jl:624
#  [2] TestHFiter(; NParamType::String, LParamType::String)
#    @ Main ~/ドキュメント/Guleria2012/TestMain.jl:127
#  [3] top-level scope
#    @ In[16]:2
#  [4] eval
#    @ ./boot.jl:373 [inlined]
#  [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
include("TestMain.jl")
TestHFiter(NParamType="SKS3",LParamType="SKSH2")
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# MethodError: no method matching getaL(::String)
# Closest candidates are:
#   getaL(::Int64) at ~/ドキュメント/Guleria2012/SkyrmeParams.jl:412
#
# Stacktrace:
#  [1] HF_iter(AN::AtomNum; MaxIter::Int64, NParamType::String, LParamType::String, α::Float64)
#    @ Main ~/ドキュメント/Guleria2012/Main.jl:624
#  [2] TestHFiter(; NParamType::String, LParamType::String)
#    @ Main ~/ドキュメント/Guleria2012/TestMain.jl:127
#  [3] top-level scope
#    @ In[17]:2
#  [4] eval
#    @ ./boot.jl:373 [inlined]
#  [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
include("TestMain.jl")
TestHFiter(NParamType="SK3",LParamType="LY1")
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# MethodError: no method matching getaL(::String)
# Closest candidates are:
#   getaL(::Int64) at ~/ドキュメント/Guleria2012/SkyrmeParams.jl:412
#
# Stacktrace:
#  [1] HF_iter(AN::AtomNum; MaxIter::Int64, NParamType::String, LParamType::String, α::Float64)
#    @ Main ~/ドキュメント/Guleria2012/Main.jl:624
#  [2] TestHFiter(; NParamType::String, LParamType::String)
#    @ Main ~/ドキュメント/Guleria2012/TestMain.jl:127
#  [3] top-level scope
#    @ In[18]:2
#  [4] eval
#    @ ./boot.jl:373 [inlined]
#  [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType="GKW2")
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# MethodError: no method matching getaL(::String)
# Closest candidates are:
#   getaL(::Int64) at ~/ドキュメント/Guleria2012/SkyrmeParams.jl:412
#
# Stacktrace:
#  [1] HF_iter(AN::AtomNum; MaxIter::Int64, NParamType::String, LParamType::String, α::Float64)
#    @ Main ~/ドキュメント/Guleria2012/Main.jl:624
#  [2] TestHFiter(; NParamType::String, LParamType::String)
#    @ Main ~/ドキュメント/Guleria2012/TestMain.jl:127
#  [3] top-level scope
#    @ In[19]:2
#  [4] eval
#    @ ./boot.jl:373 [inlined]
#  [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType="GKW3")
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# MethodError: no method matching getaL(::String)
# Closest candidates are:
#   getaL(::Int64) at ~/ドキュメント/Guleria2012/SkyrmeParams.jl:412
#
# Stacktrace:
#  [1] HF_iter(AN::AtomNum; MaxIter::Int64, NParamType::String, LParamType::String, α::Float64)
#    @ Main ~/ドキュメント/Guleria2012/Main.jl:624
#  [2] TestHFiter(; NParamType::String, LParamType::String)
#    @ Main ~/ドキュメント/Guleria2012/TestMain.jl:127
#  [3] top-level scope
#    @ In[20]:2
#  [4] eval
#    @ ./boot.jl:373 [inlined]
#  [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196
