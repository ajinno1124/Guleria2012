# %%
include("TestMain.jl")
TestInitPot()
#binを小さく取りすぎると、W/rの粗さが目立つ
# Out:
# isGuleria=0

# %%
include("TestMain.jl")
CheckInitABC()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestWronskyEuler()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
@time TestInitialCondition()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# (occ,l,j,E)=(1.0,0,0.5,-53.586517333984375)
# (occ,l,j,E)=(1.0,1,1.5,-49.429046630859375)
# (occ,l,j,E)=(1.0,1,0.5,-49.013275146484375)
# (occ,l,j,E)=(1.0,2,2.5,-44.522979736328125)
# (occ,l,j,E)=(1.0,2,1.5,-43.488922119140625)
# (occ,l,j,E)=(1.0,0,0.5,-42.163848876953125)
# (occ,l,j,E)=(1.0,3,3.5,-38.986724853515625)
# (occ,l,j,E)=(1.0,3,2.5,-37.033294677734375)
# (occ,l,j,E)=(1.0,1,1.5,-35.422210693359375)
# (occ,l,j,E)=(1.0,1,0.5,-34.571136474609375)
# (occ,l,j,E)=(1.0,4,4.5,-32.906097412109375)
# (occ,l,j,E)=(1.0,4,3.5,-29.725265502929688)
# (occ,l,j,E)=(1.0,2,2.5,-28.299880981445312)
# (occ,l,j,E)=(1.0,2,1.5,-26.557907104492188)
# (occ,l,j,E)=(1.0,5,5.5,-26.346054077148438)
# (occ,l,j,E)=(1.0,0,0.5,-26.190383911132812)
# (occ,l,j,E)=(0.0,5,4.5,-21.638687133789062)
# (occ,l,j,E)=(0.0,3,3.5,-20.881210327148438)
# (occ,l,j,E)=(0.0,6,6.5,-19.357620239257812)
# (occ,l,j,E)=(0.0,1,1.5,-18.058944702148438)
# (occ,l,j,E)=(0.0,3,2.5,-18.043746948242188)
# (occ,l,j,E)=(0.0,1,0.5,-16.884963989257812)
# (occ,l,j,E)=(0.0,4,4.5,-13.258018493652344)
# (occ,l,j,E)=(0.0,6,5.5,-12.851753234863281)
# (occ,l,j,E)=(0.0,7,7.5,-11.982612609863281)
# (occ,l,j,E)=(0.0,2,2.5,-10.092964172363281)
# (occ,l,j,E)=(0.0,4,3.5,-9.215171813964844)
# (occ,l,j,E)=(0.0,0,0.5,-8.547966003417969)
# (occ,l,j,E)=(0.0,2,1.5,-8.057929992675781)
# (occ,l,j,E)=(0.0,5,5.5,-5.552875518798828)
# (occ,l,j,E)=(0.0,7,6.5,-3.460142135620117)
# (occ,l,j,E)=(0.0,3,3.5,-2.646360397338867)
# (occ,l,j,E)=(0.0,1,1.5,-1.5855283737182617)
# (occ,l,j,E)=(0.0,1,0.5,-0.8070235252380371)
# (occ,l,j,E)=(0.0,5,4.5,-0.4087255001068115)
# (occ,l,j,E)=(0.0,3,2.5,-0.18349683284759521)
#   1.435309 seconds (6.00 M allocations: 452.544 MiB, 27.37% gc time, 66.10% compilation time)

# %%
include("TestMain.jl")
TestDensity()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
#   0.797323 seconds (4.87 M allocations: 376.392 MiB, 14.09% gc time, 59.15% compilation time)
#   0.000454 seconds (3.54 k allocations: 574.672 KiB)
# check Z=8: Integrate ρ=8.0

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType=14)
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.14710164935452294,0.08094812586448683,7.239556707455474e-6)
# 1
# diffρ=(0.024109490755566756,0.021094248500967597,1.9718173772321575e-6)
# 2
# diffρ=(0.0002783272043372672,0.0006023507345131672,7.043407559270268e-8)
# 3
# diffρ=(3.677999479067485e-5,5.9535968224963534e-5,1.97639850461581e-8)
# 4
# diffρ=(7.332351418986152e-6,1.3537917462856922e-5,4.182712467427623e-9)
# 5
# diffρ=(2.158155753581851e-6,3.766540339047651e-6,2.137582772530339e-9)
# (occ,l,j,E)=(0.5,0,0.5,-26.612991333007812)
# (occ,l,j,E)=(0.0,1,0.5,-22.495803833007812)
# (occ,l,j,E)=(0.0,1,1.5,-22.495803833007812)
# (occ,l,j,E)=(0.0,2,1.5,-17.603622436523438)
# (occ,l,j,E)=(0.0,2,2.5,-17.603622436523438)
# (occ,l,j,E)=(0.0,0,0.5,-15.815078735351562)
# (occ,l,j,E)=(0.0,3,2.5,-12.098625183105469)
# (occ,l,j,E)=(0.0,3,3.5,-12.098625183105469)
# (occ,l,j,E)=(0.0,1,0.5,-9.512657165527344)
# (occ,l,j,E)=(0.0,1,1.5,-9.512657165527344)
# (occ,l,j,E)=(0.0,4,3.5,-6.152095794677734)
# (occ,l,j,E)=(0.0,4,4.5,-6.152095794677734)
# (occ,l,j,E)=(0.0,2,1.5,-3.321561813354492)
# (occ,l,j,E)=(0.0,2,2.5,-3.321561813354492)
# (occ,l,j,E)=(0.0,0,0.5,-2.5763378143310547)

# %%
include("TestMain.jl")
TestHFiter(NParamType="SKS3",LParamType=8)
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.10758111791610453,0.09443959125049167,5.806807098285567e-6)
# 1
# diffρ=(0.015914687076707557,0.04161434071153712,4.0380125303381064e-7)
# 2
# diffρ=(0.0008385437162854292,0.0036144184132100698,3.029633077958235e-7)
# 3
# diffρ=(0.00024840362220606804,0.0007408314658111282,5.522059674891525e-8)
# 4
# diffρ=(6.71664684524834e-5,0.00021789472297884687,7.417631257459392e-9)
# 5
# diffρ=(2.2574232746369142e-5,6.245992285748925e-5,4.344582188481439e-9)
# 6
# diffρ=(7.581028030312237e-6,2.0394024646649533e-5,1.075599573698659e-9)
# 7
# diffρ=(2.551153721233717e-6,6.612823738302607e-6,6.662697804585194e-10)
# (occ,l,j,E)=(0.5,0,0.5,-24.996047973632812)
# (occ,l,j,E)=(0.0,1,0.5,-21.561813354492188)
# (occ,l,j,E)=(0.0,1,1.5,-21.561813354492188)
# (occ,l,j,E)=(0.0,2,1.5,-17.416763305664062)
# (occ,l,j,E)=(0.0,2,2.5,-17.416763305664062)
# (occ,l,j,E)=(0.0,0,0.5,-15.883712768554688)
# (occ,l,j,E)=(0.0,3,2.5,-12.662193298339844)
# (occ,l,j,E)=(0.0,3,3.5,-12.662193298339844)
# (occ,l,j,E)=(0.0,1,0.5,-10.397651672363281)
# (occ,l,j,E)=(0.0,1,1.5,-10.397651672363281)
# (occ,l,j,E)=(0.0,4,3.5,-7.394565582275391)
# (occ,l,j,E)=(0.0,4,4.5,-7.394565582275391)
# (occ,l,j,E)=(0.0,2,1.5,-4.765476226806641)
# (occ,l,j,E)=(0.0,2,2.5,-4.765476226806641)
# (occ,l,j,E)=(0.0,0,0.5,-3.986125946044922)
# (occ,l,j,E)=(0.0,5,4.5,-1.725205421447754)
# (occ,l,j,E)=(0.0,5,5.5,-1.725205421447754)

# %%
include("TestMain.jl")
TestHFiter(NParamType="SK3",LParamType=9)
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.2778758764809575,0.04608262077192356,1.007116389487871e-6)
# 1
# diffρ=(0.03724334814176001,0.025375383179170277,1.0195145902400513e-5)
# 2
# diffρ=(0.00044308262978417487,0.0008942449411685903,1.6366965872049233e-7)
# 3
# diffρ=(5.577130353366691e-5,0.00011259019220220335,6.248317105940743e-8)
# 4
# diffρ=(9.688930794780437e-6,2.1550474827437388e-5,7.316161231880634e-9)
# 5
# diffρ=(2.147761975217761e-6,4.637615926312462e-6,3.573469922410947e-9)
# (occ,l,j,E)=(0.5,0,0.5,-24.639968872070312)
# (occ,l,j,E)=(0.0,1,0.5,-21.092666625976562)
# (occ,l,j,E)=(0.0,1,1.5,-21.092666625976562)
# (occ,l,j,E)=(0.0,2,1.5,-16.801345825195312)
# (occ,l,j,E)=(0.0,2,2.5,-16.801345825195312)
# (occ,l,j,E)=(0.0,0,0.5,-15.096031188964844)
# (occ,l,j,E)=(0.0,3,2.5,-11.879158020019531)
# (occ,l,j,E)=(0.0,3,3.5,-11.879158020019531)
# (occ,l,j,E)=(0.0,1,0.5,-9.272010803222656)
# (occ,l,j,E)=(0.0,1,1.5,-9.272010803222656)
# (occ,l,j,E)=(0.0,4,3.5,-6.452396392822266)
# (occ,l,j,E)=(0.0,4,4.5,-6.452396392822266)
# (occ,l,j,E)=(0.0,2,1.5,-3.4186763763427734)
# (occ,l,j,E)=(0.0,2,2.5,-3.4186763763427734)
# (occ,l,j,E)=(0.0,0,0.5,-2.6287479400634766)
# (occ,l,j,E)=(0.0,5,4.5,-0.6812748908996582)
# (occ,l,j,E)=(0.0,5,5.5,-0.6812748908996582)

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType=27)
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.1507495196818343,0.07863094001277297,1.4751939998404733e-5)
# 1
# diffρ=(0.024041858053234957,0.021484327626591346,9.256126257355101e-9)
# 2
# diffρ=(0.00027217576744756805,0.0006316118019152234,3.0013177155049263e-9)
# 3
# diffρ=(3.7755196483543974e-5,6.393781487440264e-5,9.675645709336286e-10)
# 4
# diffρ=(8.367386087772883e-6,1.5853944909885643e-5,5.923362368759679e-10)
# 5
# diffρ=(2.750086474419094e-6,5.030664855888989e-6,2.0456144688694995e-10)
# (occ,l,j,E)=(0.5,0,0.5,-30.845184326171875)
# (occ,l,j,E)=(0.0,1,0.5,-27.768142700195312)
# (occ,l,j,E)=(0.0,1,1.5,-27.768142700195312)
# (occ,l,j,E)=(0.0,2,1.5,-23.970962524414062)
# (occ,l,j,E)=(0.0,2,2.5,-23.970962524414062)
# (occ,l,j,E)=(0.0,0,0.5,-22.354446411132812)
# (occ,l,j,E)=(0.0,3,2.5,-19.525772094726562)
# (occ,l,j,E)=(0.0,3,3.5,-19.525772094726562)
# (occ,l,j,E)=(0.0,1,0.5,-16.960403442382812)
# (occ,l,j,E)=(0.0,1,1.5,-16.960403442382812)
# (occ,l,j,E)=(0.0,4,3.5,-14.495658874511719)
# (occ,l,j,E)=(0.0,4,4.5,-14.495658874511719)
# (occ,l,j,E)=(0.0,2,1.5,-11.165290832519531)
# (occ,l,j,E)=(0.0,2,2.5,-11.165290832519531)
# (occ,l,j,E)=(0.0,0,0.5,-10.033576965332031)
# (occ,l,j,E)=(0.0,5,4.5,-8.943351745605469)
# (occ,l,j,E)=(0.0,5,5.5,-8.943351745605469)
# (occ,l,j,E)=(0.0,3,2.5,-5.148471832275391)
# (occ,l,j,E)=(0.0,3,3.5,-5.148471832275391)
# (occ,l,j,E)=(0.0,1,0.5,-3.756673812866211)
# (occ,l,j,E)=(0.0,1,1.5,-3.756673812866211)
# (occ,l,j,E)=(0.0,6,5.5,-2.941019058227539)
# (occ,l,j,E)=(0.0,6,6.5,-2.941019058227539)

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType=28)
