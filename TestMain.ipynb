# %%
include("TestMain.jl")
TestInitPot()
#binを小さく取りすぎると、W/rの粗さが目立つ
# Out:
# isGuleria=0

# %%
include("TestMain.jl")
CheckInitABC()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestWronskyEuler()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
@time TestInitialCondition()
# Out:
# isGuleria=0
# (occ,l,j,E)=(1.0,0,0.5,-53.586463928222656)
# (occ,l,j,E)=(1.0,1,1.5,-49.429054260253906)
# (occ,l,j,E)=(1.0,1,0.5,-49.013328552246094)
# (occ,l,j,E)=(1.0,2,2.5,-44.522972106933594)
# (occ,l,j,E)=(1.0,2,1.5,-43.48896026611328)
# (occ,l,j,E)=(1.0,0,0.5,-42.16388702392578)
# (occ,l,j,E)=(1.0,3,3.5,-38.986778259277344)
# (occ,l,j,E)=(1.0,3,2.5,-37.03329086303711)
# (occ,l,j,E)=(1.0,1,1.5,-35.42219161987305)
# (occ,l,j,E)=(1.0,1,0.5,-34.57109451293945)
# (occ,l,j,E)=(1.0,4,4.5,-32.90605545043945)
# (occ,l,j,E)=(1.0,4,3.5,-29.725284576416016)
# (occ,l,j,E)=(1.0,2,2.5,-28.299884796142578)
# (occ,l,j,E)=(1.0,2,1.5,-26.557903289794922)
# (occ,l,j,E)=(1.0,5,5.5,-26.346073150634766)
# (occ,l,j,E)=(1.0,0,0.5,-26.19039535522461)
# (occ,l,j,E)=(0.0,5,4.5,-21.63869857788086)
# (occ,l,j,E)=(0.0,3,3.5,-20.881214141845703)
# (occ,l,j,E)=(0.0,6,6.5,-19.357624053955078)
# (occ,l,j,E)=(0.0,1,1.5,-18.05893898010254)
# (occ,l,j,E)=(0.0,3,2.5,-18.04375648498535)
# ...

# %%
include("TestMain.jl")
TestDensity()
# Out:
# isGuleria=0
#   0.245947 seconds (1.29 M allocations: 84.215 MiB, 10.16% gc time, 82.01% compilation time)
#   0.000266 seconds (3.54 k allocations: 574.672 KiB)
# check Z=8: Integrate ρ=7.995985420132063
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType=14)
# Out:
# isGuleria=0
# diffρ=(0.14706546331816406,0.0809442601637335,7.163372448215792e-6)
# 1
# diffρ=(0.024105592486369794,0.02109500157849608,1.968223873883661e-6)
# 2
# diffρ=(0.00027796580146321575,0.0006016379547151697,7.074820436447454e-8)
# 3
# diffρ=(3.65887065397755e-5,5.936709209007621e-5,1.982863536510437e-8)
# 4
# diffρ=(7.292230063650355e-6,1.3478044882594918e-5,4.210308962432182e-9)
# 5
# diffρ=(2.151746149132936e-6,3.7687826257205305e-6,2.153549471680143e-9)
# (occ,l,j,E)=(0.5,0,0.5,-26.611347198486328)
# (occ,l,j,E)=(0.0,1,0.5,-22.49502182006836)
# (occ,l,j,E)=(0.0,1,1.5,-22.49502182006836)
# (occ,l,j,E)=(0.0,2,1.5,-17.60308265686035)
# (occ,l,j,E)=(0.0,2,2.5,-17.60308265686035)
# (occ,l,j,E)=(0.0,0,0.5,-15.812883377075195)
# (occ,l,j,E)=(0.0,3,2.5,-12.098188400268555)
# (occ,l,j,E)=(0.0,3,3.5,-12.098188400268555)
# (occ,l,j,E)=(0.0,1,0.5,-9.5115327835083)
# (occ,l,j,E)=(0.0,1,1.5,-9.5115327835083)
# (occ,l,j,E)=(0.0,4,3.5,-6.151690483093262)
# ...

# %%
include("TestMain.jl")
TestHFiter(NParamType="SKS3",LParamType=8)
# Out:
# isGuleria=0
# diffρ=(0.10753018716896563,0.0944533921637763,5.75729813711817e-6)
# 1
# diffρ=(0.015908815454404448,0.04161583008045833,4.0108590795511676e-7)
# 2
# diffρ=(0.000837467306930175,0.003613087731071984,3.035348344615314e-7)
# 3
# diffρ=(0.00024746522299489706,0.0007388223585097649,5.516645807963445e-8)
# 4
# diffρ=(6.672209578885657e-5,0.00021682966692663293,7.393703103607961e-9)
# 5
# diffρ=(2.238547503459045e-5,6.20214837898201e-5,4.341732053838725e-9)
# 6
# diffρ=(7.5003737578917815e-6,2.021098013322979e-5,1.1194738837610238e-9)
# 7
# diffρ=(2.5255862237268615e-6,6.543573224211794e-6,6.731332903068639e-10)
# (occ,l,j,E)=(0.5,0,0.5,-24.995250701904297)
# (occ,l,j,E)=(0.0,1,0.5,-21.56137466430664)
# (occ,l,j,E)=(0.0,1,1.5,-21.56137466430664)
# (occ,l,j,E)=(0.0,2,1.5,-17.41644859313965)
# (occ,l,j,E)=(0.0,2,2.5,-17.41644859313965)
# (occ,l,j,E)=(0.0,0,0.5,-15.882482528686523)
# (occ,l,j,E)=(0.0,3,2.5,-12.661867141723633)
# (occ,l,j,E)=(0.0,3,3.5,-12.661867141723633)
# ...

# %%
include("TestMain.jl")
TestHFiter(NParamType="SK3",LParamType=9)
# Out:
# isGuleria=0
# diffρ=(0.2777346409143637,0.046103886126677124,9.791867851966028e-7)
# 1
# diffρ=(0.0372323997448678,0.02537713525671736,1.0148182546168653e-5)
# 2
# diffρ=(0.0004436247767405733,0.0008947105368485059,1.6500049592134876e-7)
# 3
# diffρ=(5.573071225597776e-5,0.00011244166089712123,6.232303106121318e-8)
# 4
# diffρ=(9.657527327156587e-6,2.1448414585001043e-5,7.418442359079152e-9)
# 5
# diffρ=(2.1343600531128465e-6,4.613618522706605e-6,3.522826665019257e-9)
# (occ,l,j,E)=(0.5,0,0.5,-24.63907241821289)
# (occ,l,j,E)=(0.0,1,0.5,-21.092281341552734)
# (occ,l,j,E)=(0.0,1,1.5,-21.092281341552734)
# (occ,l,j,E)=(0.0,2,1.5,-16.801042556762695)
# (occ,l,j,E)=(0.0,2,2.5,-16.801042556762695)
# (occ,l,j,E)=(0.0,0,0.5,-15.094461441040039)
# (occ,l,j,E)=(0.0,3,2.5,-11.878824234008789)
# (occ,l,j,E)=(0.0,3,3.5,-11.878824234008789)
# (occ,l,j,E)=(0.0,1,0.5,-9.271206855773926)
# (occ,l,j,E)=(0.0,1,1.5,-9.271206855773926)
# (occ,l,j,E)=(0.0,4,3.5,-6.452021598815918)
# ...

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType=27)
# Out:
# isGuleria=0
# diffρ=(0.15071084089907777,0.07862756320056626,1.4729977632483656e-5)
# 1
# diffρ=(0.024038244633684796,0.021485013064107838,9.499248089384286e-9)
# 2
# diffρ=(0.00027177738562305894,0.0006307592447057425,3.033761705226995e-9)
# 3
# diffρ=(3.756049275090414e-5,6.377517949755322e-5,9.878302515689567e-10)
# 4
# diffρ=(8.32307867116112e-6,1.5800996321504866e-5,5.667689634196811e-10)
# 5
# diffρ=(2.7429981892712533e-6,5.021586976038179e-6,2.358060382940023e-10)
# (occ,l,j,E)=(0.5,0,0.5,-30.845050811767578)
# (occ,l,j,E)=(0.0,1,0.5,-27.768001556396484)
# (occ,l,j,E)=(0.0,1,1.5,-27.768001556396484)
# (occ,l,j,E)=(0.0,2,1.5,-23.970813751220703)
# (occ,l,j,E)=(0.0,2,2.5,-23.970813751220703)
# (occ,l,j,E)=(0.0,0,0.5,-22.354106903076172)
# (occ,l,j,E)=(0.0,3,2.5,-19.525585174560547)
# (occ,l,j,E)=(0.0,3,3.5,-19.525585174560547)
# (occ,l,j,E)=(0.0,1,0.5,-16.96009635925293)
# (occ,l,j,E)=(0.0,1,1.5,-16.96009635925293)
# (occ,l,j,E)=(0.0,4,3.5,-14.495420455932617)
# ...

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType=28)
# Out:
# isGuleria=0
# diffρ=(0.1518991889367056,0.07778832087205267,3.674765428091861e-5)
# 1
# diffρ=(0.024033141603238994,0.021582763494324083,3.2185823361368505e-7)
# 2
# diffρ=(0.00027198733546060586,0.0006412002925789367,6.866431881674012e-9)
# 3
# diffρ=(3.814407447322579e-5,6.542701296681539e-5,2.07355707634633e-9)
# 4
# diffρ=(8.669429940462077e-6,1.6544078449508106e-5,1.1532840562835445e-10)
# 5
# diffρ=(2.917636888795249e-6,5.3834990969223125e-6,1.1015165912209086e-10)
# (occ,l,j,E)=(0.5,0,0.5,-26.73391342163086)
# (occ,l,j,E)=(0.0,1,0.5,-23.751049041748047)
# (occ,l,j,E)=(0.0,1,1.5,-23.751049041748047)
# (occ,l,j,E)=(0.0,2,1.5,-20.04964828491211)
# (occ,l,j,E)=(0.0,2,2.5,-20.04964828491211)
# (occ,l,j,E)=(0.0,0,0.5,-18.418893814086914)
# (occ,l,j,E)=(0.0,3,2.5,-15.702600479125977)
# (occ,l,j,E)=(0.0,3,3.5,-15.702600479125977)
# (occ,l,j,E)=(0.0,1,0.5,-13.12006950378418)
# (occ,l,j,E)=(0.0,1,1.5,-13.12006950378418)
# (occ,l,j,E)=(0.0,4,3.5,-10.775880813598633)
# ...

# %%
include("TestMain.jl")
TestHFiter(AN=AtomNum(57,81,1),NParamType="SLy4",LParamType=47,α=0.1)
# Out:
# isGuleria=0
# diffρ=(0.1529883756022895,0.03073308399022689,3.480068014484467e-5)
# 1
# diffρ=(0.0006348239310028773,0.0004912383727718443,1.6929879921148962e-7)
# 2
# diffρ=(0.00041254301514784345,0.0002910676728801563,1.0964571723713153e-7)
# 3
# diffρ=(0.00026905383041264343,0.00017658465040482418,7.270189354004058e-8)
# 4
# diffρ=(0.0001761667054043473,0.00010960361909199479,4.90611896865895e-8)
# 5
# diffρ=(0.03417111061407787,6.928054221352739e-5,3.3704831598038175e-8)
# 6
# diffρ=(0.03443128472904931,8.347779880182068e-5,2.9141457356981476e-8)
# 7
# diffρ=(0.034670810414047785,3.476267846810344e-5,3.1041835381281225e-8)
# 8
# diffρ=(2.8528114649522035e-5,5.138651921712845e-5,3.0239058100756107e-8)
# 9
# diffρ=(0.03478741966839175,3.626774903746144e-5,2.2289919286276847e-8)
# 10
# diffρ=(0.03534544697643611,2.1492983828290723e-5,3.720402435218595e-8)
# 11
# diffρ=(1.1896746519538437e-5,2.6911306976741773e-5,2.5440395813612414e-8)
# 12
# ...

# %%
include("TestMain.jl")
TestHFiter(AN=AtomNum(57,81,1),NParamType="SLy4",LParamType=47,α=0.5)
# Out:
# isGuleria=0
# diffρ=(0.1529883756022895,0.03073308399022689,3.480068014484467e-5)
# 1
# diffρ=(0.06299773212524867,0.011521140072495209,4.475853583817048e-6)
# 2
# diffρ=(0.047574603607850374,0.0027500909103131198,2.355799382610032e-6)
# 3
# diffρ=(0.04760088995196338,0.0017051830192339865,1.9916871506164233e-6)
# 4
# diffρ=(0.04739303631276484,0.001610830131795228,2.1230609135211616e-6)
# 5
# diffρ=(0.04720341130032569,0.001519958655957819,2.08557592444362e-6)
# 6
# diffρ=(0.04726312270216379,0.0015322871782684733,2.1417536776933722e-6)
# 7
# diffρ=(0.04714731214785298,0.0014919094271937825,2.0958864534452353e-6)
# 8
# diffρ=(0.04717579057474785,0.0015084522181956503,2.1334320546896083e-6)
# 9
# diffρ=(0.047130500843894876,0.0014868156949803192,2.0991034957263176e-6)
# 10
# diffρ=(0.04713789226049471,0.0014977613290557165,2.124703480625207e-6)
# 11
# diffρ=(0.04712096419136308,0.001485848814551086,2.1013628938758535e-6)
# 12
# ...
