# %%
include("TestMain.jl")
TestInitPot()
#binを小さく取りすぎると、W/rの粗さが目立つ

# %%
include("TestMain.jl")
CheckInitABC()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestWronskyEuler()
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
@time TestInitialCondition()
# Out:
# (occ,l,j,E)=(1.0,0,0.5,-53.586517333984375)
# (occ,l,j,E)=(1.0,1,1.5,-49.429046630859375)
# (occ,l,j,E)=(1.0,1,0.5,-49.013275146484375)
# (occ,l,j,E)=(1.0,2,2.5,-44.522979736328125)
# (occ,l,j,E)=(1.0,2,1.5,-43.488922119140625)
# (occ,l,j,E)=(1.0,0,0.5,-42.163787841796875)
# (occ,l,j,E)=(1.0,3,3.5,-38.986724853515625)
# (occ,l,j,E)=(1.0,3,2.5,-37.033294677734375)
# (occ,l,j,E)=(1.0,1,1.5,-35.422088623046875)
# (occ,l,j,E)=(1.0,1,0.5,-34.571014404296875)
# (occ,l,j,E)=(1.0,4,4.5,-32.906036376953125)
# (occ,l,j,E)=(1.0,4,3.5,-29.725234985351562)
# (occ,l,j,E)=(1.0,2,2.5,-28.299758911132812)
# (occ,l,j,E)=(1.0,2,1.5,-26.557754516601562)
# (occ,l,j,E)=(1.0,5,5.5,-26.346023559570312)
# (occ,l,j,E)=(1.0,0,0.5,-26.190048217773438)
# (occ,l,j,E)=(0.0,5,4.5,-21.638656616210938)
# (occ,l,j,E)=(0.0,3,3.5,-20.881027221679688)
# (occ,l,j,E)=(0.0,6,6.5,-19.357589721679688)
# (occ,l,j,E)=(0.0,1,1.5,-18.058456420898438)
# (occ,l,j,E)=(0.0,3,2.5,-18.043563842773438)
# (occ,l,j,E)=(0.0,1,0.5,-16.884445190429688)
# (occ,l,j,E)=(0.0,4,4.5,-13.257820129394531)
# (occ,l,j,E)=(0.0,6,5.5,-12.851692199707031)
# (occ,l,j,E)=(0.0,7,7.5,-11.982551574707031)
# (occ,l,j,E)=(0.0,2,2.5,-10.092414855957031)
# (occ,l,j,E)=(0.0,4,3.5,-9.214958190917969)
# (occ,l,j,E)=(0.0,0,0.5,-8.546928405761719)
# (occ,l,j,E)=(0.0,2,1.5,-8.057365417480469)
# (occ,l,j,E)=(0.0,5,5.5,-5.552661895751953)
# (occ,l,j,E)=(0.0,7,6.5,-3.4600887298583984)
# (occ,l,j,E)=(0.0,3,3.5,-2.645872116088867)
# (occ,l,j,E)=(0.0,1,1.5,-1.5847101211547852)
# (occ,l,j,E)=(0.0,1,0.5,-0.8063321113586426)
# (occ,l,j,E)=(0.0,5,4.5,-0.40851616859436035)
# (occ,l,j,E)=(0.0,3,2.5,-0.18308937549591064)
#   1.869656 seconds (20.13 M allocations: 1.571 GiB, 13.78% gc time, 27.15% compilation time)
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestDensity()
# Out:
#   1.173491 seconds (17.30 M allocations: 1.359 GiB, 27.65% gc time, 22.85% compilation time)
#   0.000886 seconds (15.69 k allocations: 2.399 MiB)
# check Z=8: Integrate ρ=8.0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType="HPL2")
# Out:
# diffρ=(0.14655482606357137,0.0803078263959931,1.1359224725727733e-5)
# 1
# diffρ=(0.023849909131862516,0.019872835225095337,2.2951375402462177e-6)
# 2
# diffρ=(0.0002169209880803112,0.0005034267946542363,7.649064229916613e-8)
# 3
# diffρ=(2.858118626915265e-5,4.495361919849069e-5,1.7235028944232404e-8)
# 4
# diffρ=(5.525171936258647e-6,1.1219423262502049e-5,3.0826502413570346e-9)
# 5
# diffρ=(1.8374328861315455e-6,3.0875316431069254e-6,1.5472297175207913e-9)
# (occ,l,j,E)=(0.5,0,0.5,-26.668319702148438)
# (occ,l,j,E)=(0.0,1,0.5,-22.519424438476562)
# (occ,l,j,E)=(0.0,1,1.5,-22.519424438476562)
# (occ,l,j,E)=(0.0,2,1.5,-17.620773315429688)
# (occ,l,j,E)=(0.0,2,2.5,-17.620773315429688)
# (occ,l,j,E)=(0.0,0,0.5,-15.894210815429688)
# (occ,l,j,E)=(0.0,3,2.5,-12.121055603027344)
# (occ,l,j,E)=(0.0,3,3.5,-12.121055603027344)
# (occ,l,j,E)=(0.0,1,0.5,-9.582252502441406)
# (occ,l,j,E)=(0.0,1,1.5,-9.582252502441406)
# (occ,l,j,E)=(0.0,4,3.5,-6.185153961181641)
# (occ,l,j,E)=(0.0,4,4.5,-6.185153961181641)
# (occ,l,j,E)=(0.0,2,1.5,-3.382017135620117)
# (occ,l,j,E)=(0.0,2,2.5,-3.382017135620117)
# (occ,l,j,E)=(0.0,0,0.5,-2.6496639251708984)
# (occ,l,j,E)=(0.0,5,4.5,-0.027557656168937683)
# (occ,l,j,E)=(0.0,5,5.5,-0.027557656168937683)
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestHFiter(NParamType="SKS3",LParamType="SKSH2")
# Out:
# diffρ=(0.10544686203290086,0.08414116788915896,9.513213740603858e-6)
# 1
# diffρ=(0.01398236582785144,0.028783816801833673,1.617068724044474e-6)
# 2
# diffρ=(0.00033140960453226855,0.0015346277974980227,4.2865315763316e-8)
# 3
# diffρ=(0.00010081738191179766,0.0002915933792829647,2.245373887458623e-8)
# 4
# diffρ=(2.7439639891381638e-5,9.085734421835617e-5,4.114664844836523e-9)
# 5
# diffρ=(1.0315790647634247e-5,2.629409666991551e-5,2.5843268000673256e-9)
# 6
# diffρ=(3.671215083500124e-6,9.500079407696028e-6,7.410509338295627e-10)
# (occ,l,j,E)=(0.5,0,0.5,-25.052597045898438)
# (occ,l,j,E)=(0.0,1,0.5,-21.596878051757812)
# (occ,l,j,E)=(0.0,1,1.5,-21.596878051757812)
# (occ,l,j,E)=(0.0,2,1.5,-17.444869995117188)
# (occ,l,j,E)=(0.0,2,2.5,-17.444869995117188)
# (occ,l,j,E)=(0.0,0,0.5,-15.957138061523438)
# (occ,l,j,E)=(0.0,3,2.5,-12.691154479980469)
# (occ,l,j,E)=(0.0,3,3.5,-12.691154479980469)
# (occ,l,j,E)=(0.0,1,0.5,-10.468818664550781)
# (occ,l,j,E)=(0.0,1,1.5,-10.468818664550781)
# (occ,l,j,E)=(0.0,4,3.5,-7.428623199462891)
# (occ,l,j,E)=(0.0,4,4.5,-7.428623199462891)
# (occ,l,j,E)=(0.0,2,1.5,-4.829013824462891)
# (occ,l,j,E)=(0.0,2,2.5,-4.829013824462891)
# (occ,l,j,E)=(0.0,0,0.5,-4.059291839599609)
# (occ,l,j,E)=(0.0,5,4.5,-1.7667322158813477)
# (occ,l,j,E)=(0.0,5,5.5,-1.7667322158813477)
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType="GKW2")
# Out:
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# DomainError with -4.489313774270276:
# Exponentiation yielding a complex result requires a complex argument.
# Replace x^y with (x+0im)^y, Complex(x)^y, or similar.
#
# Stacktrace:
#   [1] throw_exp_domainerror(x::Float64)
#     @ Base.Math .\math.jl:37
#   [2] ^
#     @ .\math.jl:909 [inlined]
#   [3] _broadcast_getindex_evalf
#     @ .\broadcast.jl:670 [inlined]
#   [4] _broadcast_getindex
#     @ .\broadcast.jl:643 [inlined]
#   [5] _getindex
#     @ .\broadcast.jl:667 [inlined]
#   [6] _getindex
#     @ .\broadcast.jl:666 [inlined]
#   [7] _broadcast_getindex
#     @ .\broadcast.jl:642 [inlined]
#   [8] getindex
#     @ .\broadcast.jl:597 [inlined]
#   [9] macro expansion
#     @ .\broadcast.jl:961 [inlined]
#  [10] macro expansion
#     @ .\simdloop.jl:77 [inlined]
#  [11] copyto!
#     @ .\broadcast.jl:960 [inlined]
#  [12] copyto!
#     @ .\broadcast.jl:913 [inlined]
#  [13] materialize!
#     @ .\broadcast.jl:871 [inlined]
#  [14] materialize!
#     @ .\broadcast.jl:868 [inlined]
#  [15] RadWaveFunc(E::Float64, QN::QuantumNumber, A::Vector{Float64}, C::Vector{Float64}, rmesh::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64})
#     @ Main C:\Users\jinno\OneDrive\progmrams\Guleria2012\Main.jl:213
#  [16] CalcStates(QN::QuantumNumber, h2mB::Vector{Float64}, dh2mB::Vector{Float64}, ddh2mB::Vector{Float64}, VB::Vector{Float64}, WB::Vector{Float64}, rmesh::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64})
#     @ Main C:\Users\jinno\OneDrive\progmrams\Guleria2012\Main.jl:233
#  [17] CalcAllStates(h2m::Matrix{Float64}, dh2m::Matrix{Float64}, ddh2m::Matrix{Float64}, V::Matrix{Float64}, W::Matrix{Float64}, rmesh::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64})
#     @ Main C:\Users\jinno\OneDrive\progmrams\Guleria2012\Main.jl:248
#  [18] HF_iter(AN::AtomNum; MaxIter::Int64, NParamType::String, LParamType::String, α::Float64)
#     @ Main C:\Users\jinno\OneDrive\progmrams\Guleria2012\Main.jl:626
#  [19] TestHFiter(; NParamType::String, LParamType::String)
#     @ Main C:\Users\jinno\OneDrive\progmrams\Guleria2012\TestMain.jl:127
#  [20] top-level scope
#     @ In[17]:2
#  [21] eval
#     @ .\boot.jl:373 [inlined]
#  [22] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1196

# %%
include("TestMain.jl")
TestHFiter(NParamType="SLy4",LParamType="GKW3")
# Out:
# diffρ=(0.14716895835026597,0.07476622344097954,0.00044307158242632653)
# 1
# diffρ=(0.022449391375858198,0.019261939754511084,8.362386350260543e-7)
# 2
# diffρ=(0.00019201153153051303,0.0004944422299301437,7.0487350925107455e-9)
# 3
# diffρ=(2.417237146008583e-5,4.283647866529098e-5,8.30063899920326e-10)
# 4
# diffρ=(5.557548450344962e-6,1.2031438437708326e-5,1.7870044239374368e-10)
# 5
# diffρ=(2.2140723465715553e-6,4.07848018919052e-6,1.0151522580307453e-10)
# (occ,l,j,E)=(0.5,0,0.5,-24.544937133789062)
# (occ,l,j,E)=(0.0,1,0.5,-18.002700805664062)
# (occ,l,j,E)=(0.0,1,1.5,-18.002700805664062)
# (occ,l,j,E)=(0.0,2,1.5,-9.933204650878906)
# (occ,l,j,E)=(0.0,2,2.5,-9.933204650878906)
# (occ,l,j,E)=(0.0,0,0.5,-2.388376235961914)
# (occ,l,j,E)=(0.0,3,2.5,-1.5340509414672852)
# (occ,l,j,E)=(0.0,3,3.5,-1.5340509414672852)
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
