# %%
#not converged
include("TestMain.jl")
TestHFiter(AN=AtomNum(57,81,0),NParamType="SLy4",LParamType=-1,α=0.5)
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.1537775780152873,0.03013318510152431,0.0)
# 1
# diffρ=(0.06255657023556266,0.01150906123449832,0.0)
# 2
# diffρ=(0.04715878539569528,0.00270573212393268,0.0)
# 3
# diffρ=(0.0472296260520846,0.0016400870354596206,0.0)
# 4
# diffρ=(0.046995308432055266,0.0015659065367055838,0.0)
# 5
# diffρ=(0.04681408683908462,0.0014643309726663127,0.0)
# 6
# diffρ=(0.04686079065901958,0.00148721620079991,0.0)
# 7
# diffρ=(0.04675228460315048,0.001439822668743683,0.0)
# 8
# diffρ=(0.04677362300726484,0.0014621896545777724,0.0)
# 9
# diffρ=(0.046731962029248515,0.0014361344455477345,0.0)
# 10
# diffρ=(0.046735212232406675,0.0014503476729988763,0.0)
# 11
# diffρ=(0.046720746376102226,0.0014358170450997363,0.0)
# 12
# diffρ=(0.04671863893908098,0.0014440614270870042,0.0)
# 13
# diffρ=(0.04671359798652815,0.001436115658578934,0.0)
# 14
# ...

# %%
include("TestMain.jl")
TestHFiter(AN=AtomNum(57,81,0),NParamType="SLy4",LParamType=-1,α=0.1)
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.1537775780152873,0.03013318510152431,0.0)
# 1
# diffρ=(0.0006280118062103268,0.0004905373530441758,0.0)
# 2
# diffρ=(0.00040852247615347616,0.00029195675247629656,0.0)
# 3
# diffρ=(0.0002665485039384527,0.0001780713447155748,0.0)
# 4
# diffρ=(0.0001745267016909116,0.00011099171920753548,0.0)
# 5
# diffρ=(0.034103489189892804,7.053796636745975e-5,0.0)
# 6
# diffρ=(0.03434589838294856,8.628215343536637e-5,0.0)
# 7
# diffρ=(0.03459733194544778,3.543501172135624e-5,0.0)
# 8
# diffρ=(2.7287631501203575e-5,5.330053940027737e-5,0.0)
# 9
# diffρ=(0.034702106057158455,3.790429657843481e-5,0.0)
# 10
# diffρ=(0.03526232815626755,2.1573572058778594e-5,0.0)
# 11
# diffρ=(1.1272867999049386e-5,2.8085535019478275e-5,0.0)
# 12
# diffρ=(6.965968683751623e-6,2.0120285567763952e-5,0.0)
# 13
# diffρ=(0.03482746404737363,1.468593893034506e-5,0.0)
# 14
# ...

# %%
include("TestMain.jl")
TestHFiter(AN=AtomNum(57,81,0),NParamType="SLy4",LParamType=-1,α=0.05)
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.1537775780152873,0.03013318510152431,0.0)
# 1
# diffρ=(0.0001564887267816816,0.00012366434054860687,0.0)
# 2
# diffρ=(0.00012785470597499846,9.655482376229789e-5,0.0)
# 3
# diffρ=(0.00010443101081767652,7.582085610160259e-5,0.0)
# 4
# diffρ=(8.53074891836755e-5,5.986874264420761e-5,0.0)
# 5
# diffρ=(6.979053565594249e-5,4.745377614866651e-5,0.0)
# 6
# diffρ=(5.707190291133374e-5,3.7827151010131336e-5,0.0)
# 7
# diffρ=(4.6740140432639614e-5,3.0281463156135355e-5,0.0)
# 8
# diffρ=(3.828510160265824e-5,2.4321331347337764e-5,0.0)
# 9
# diffρ=(3.1392458176843024e-5,1.9583336290055985e-5,0.0)
# 10
# diffρ=(2.5774547194009072e-5,1.5895712173273326e-5,0.0)
# 11
# diffρ=(0.033540631650047364,1.2909757221984335e-5,0.0)
# 12
# diffρ=(1.344918172266584e-5,2.0598335268424143e-5,0.0)
# 13
# diffρ=(1.0939394624398708e-5,1.7420872565705267e-5,0.0)
# 14
# ...

# %%
#too small to iterate
include("TestMain.jl")
TestHFiter(AN=AtomNum(57,81,0),NParamType="SLy4",LParamType=-1,α=0.01)
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.1537775780152873,0.03013318510152431,0.0)
# 1
# diffρ=(6.241112395580607e-6,4.985558262413487e-6,0.0)

# %%
include("TestMain.jl")
Test138La()
# Out:
# isGuleria=0
# WARNING: replacing module NuclParameters.
# WARNING: replacing module LambdaParameters.
# WARNING: replacing module MyLib.
# diffρ=(0.1537775780152873,0.03013318510152431,0.0)
# 1
# diffρ=(6.241112395580607e-6,4.985558262413487e-6,0.0)
# Using α=0.01, do not converge.
# diffρ=(0.1537775780152873,0.03013318510152431,0.0)
# 1
# diffρ=(2.4982326149263805e-5,1.987882495642785e-5,0.0)
# 2
# diffρ=(2.3117115346474965e-5,1.8076181481916972e-5,0.0)
# 3
# diffρ=(2.1376562150089018e-5,1.6414280955584338e-5,0.0)
# 4
# diffρ=(1.9764104403013316e-5,1.4925718333767276e-5,0.0)
# 5
# diffρ=(1.8276743130780483e-5,1.3585902367620255e-5,0.0)
# 6
# diffρ=(1.6909069803352463e-5,1.2382613605852941e-5,0.0)
# 7
# diffρ=(1.56263493680089e-5,1.1311447018575543e-5,0.0)
# 8
# diffρ=(1.4448698698329487e-5,1.0289609445790391e-5,0.0)
# 9
# diffρ=(1.3371510981621656e-5,9.405321163032103e-6,0.0)
# 10
# diffρ=(1.236323263382057e-5,8.599598933404591e-6,0.0)
# 11
# ...
